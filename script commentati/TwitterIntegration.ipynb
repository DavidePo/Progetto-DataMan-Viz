# %%
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('mongo', 27017, username='admin', password='DataMan2019!')

# %%
Twitter_db = client.Twitter_indicator
indicator = Twitter_db.indicator

# %%
import pandas as pd

# %%
indicator_db = mongo_db = list(client.twitter_indicator.indicator.find())

# %%
indicator_db
# Out:
#                                      _id  AMSTERDAM  ATHENS  BARCELONA  \
# 0   {'$oid': '5e173c97c53bbdea5a789687'}       4829    1000       9643
# 1   {'$oid': '5e174b4cc53bbdea5a789689'}       4562    1215       9762
# 2   {'$oid': '5e17a726c53bbdea5a78968b'}       6955    1394      14012
# 3   {'$oid': '5e18531ebf9f5fe75db44431'}       7756    1453      14622
# 4   {'$oid': '5e1876bdbf9f5fe75db44433'}       7853    1545      15955
# 5   {'$oid': '5e18b1f5bf9f5fe75db44435'}       8465    2099      10107
# 6   {'$oid': '5e19b8692004a97b31f9ebb6'}       7240    1483       3100
# 7   {'$oid': '5e19cc182004a97b31f9ebb8'}       6404    1289      10916
# 8   {'$oid': '5e1a59742004a97b31f9ebba'}       6508    1402      11768
# 9   {'$oid': '5e1b1f6d22077a33a07a3eb1'}       8063    1507      16596
# 10  {'$oid': '5e1b418022077a33a07a3eb3'}       7945    1613      13770
# 11  {'$oid': '5e1b626c22077a33a07a3eb5'}       7843    1394      12692
#
# ...

# %%
del indicator_db['_id']

# %%
indicator_db = indicator_db.T

# %%
indicator_db.columns = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']

# %%
indicator_db
# Out:
#               jan    feb    mar    apr    may    jun    jul    aug    sep  \
# AMSTERDAM    4829   4562   6955   7756   7853   8465   7240   6404   6508
# ATHENS       1000   1215   1394   1453   1545   2099   1483   1289   1402
# BARCELONA    9643   9762  14012  14622  15955  10107   3100  10916  11768
# BERLIN       7301   7041  12114  13415  13238  14827  11923  11112  11900
# BRATISLAVA    343    257    383    343    460    427    375    364    213
# BRUSSELS      235    229     90    379    291    286    331    311    270
# BUDAPEST     1853   1551   2283   2100   2653   2800   2577    775   2288
# COPENHAGEN    892    872   1346   1517   1706   1928   1605   1621   1444
# DUBLIN       3884   3858   7084   7166   8054   9170   7208   7093   7758
# EDINBURGH    2322   1898   3886   4538   5222   5799   5391   7804   4486
# GENEVA        494    354   1084    706   1016    941    794    796    697
# HAMBURG      2390   2152   3082   2962   3071   3146   2583   2376   2138
# ...

# %%
indicator_db['total'] = indicator_db.sum(axis=1)

# %%
indicator_db = indicator_db.reset_index()

# %%
indicator_db = indicator_db.rename(columns={'index':'city'})
indicator_db
# Out:
#           city    jan    feb    mar    apr    may    jun    jul    aug    sep  \
# 0    AMSTERDAM   4829   4562   6955   7756   7853   8465   7240   6404   6508
# 1       ATHENS   1000   1215   1394   1453   1545   2099   1483   1289   1402
# 2    BARCELONA   9643   9762  14012  14622  15955  10107   3100  10916  11768
# 3       BERLIN   7301   7041  12114  13415  13238  14827  11923  11112  11900
# 4   BRATISLAVA    343    257    383    343    460    427    375    364    213
# 5     BRUSSELS    235    229     90    379    291    286    331    311    270
# 6     BUDAPEST   1853   1551   2283   2100   2653   2800   2577    775   2288
# 7   COPENHAGEN    892    872   1346   1517   1706   1928   1605   1621   1444
# 8       DUBLIN   3884   3858   7084   7166   8054   9170   7208   7093   7758
# 9    EDINBURGH   2322   1898   3886   4538   5222   5799   5391   7804   4486
# 10      GENEVA    494    354   1084    706   1016    941    794    796    697
# ...

# %%
indicator_db['city']= indicator_db['city'].str.capitalize()

# %%
indicator_db
# Out:
#           city    jan    feb    mar    apr    may    jun    jul    aug    sep  \
# 0    Amsterdam   4829   4562   6955   7756   7853   8465   7240   6404   6508
# 1       Athens   1000   1215   1394   1453   1545   2099   1483   1289   1402
# 2    Barcelona   9643   9762  14012  14622  15955  10107   3100  10916  11768
# 3       Berlin   7301   7041  12114  13415  13238  14827  11923  11112  11900
# 4   Bratislava    343    257    383    343    460    427    375    364    213
# 5     Brussels    235    229     90    379    291    286    331    311    270
# 6     Budapest   1853   1551   2283   2100   2653   2800   2577    775   2288
# 7   Copenhagen    892    872   1346   1517   1706   1928   1605   1621   1444
# 8       Dublin   3884   3858   7084   7166   8054   9170   7208   7093   7758
# 9    Edinburgh   2322   1898   3886   4538   5222   5799   5391   7804   4486
# 10      Geneva    494    354   1084    706   1016    941    794    796    697
# ...

# %%
indicator.insert_many(indicator_db.to_dict('records'))
