# %%
#importo le librerie per poter creare gli indicatori
from pymongo import MongoClient
import pandas as pd

# %%
client = MongoClient('mongo', 27017, username='admin', password='DataMan2019!')

# %%
#importo il dataset da Mongo con tutti i 92 indici 
db = client.Integrated_db
db_int = db.integrated_collection
db_int_pd = pd.DataFrame(list(db_int.find({})))

# %%
db_int_pd
# Out:
#                            _id        city  \
# 0     5e1c9c4b5115a1e088982e9a    Brussels
# 1     5e1c9c4b5115a1e088982e9b   Antwerpen
# 2     5e1c9c4b5115a1e088982e9c        Gent
# 3     5e1c9c4b5115a1e088982e9d   Charleroi
# 4     5e1c9c4b5115a1e088982e9e       Liège
# ...                        ...         ...
# 997   5e1c9c4b5115a1e08898327f  St. Gallen
# 998   5e1c9c4b5115a1e088983280      Luzern
# 999   5e1c9c4b5115a1e088983281      Lugano
# 1000  5e1c9c4b5115a1e088983282        Biel
# 1001  5e1c9c4b5115a1e088983283   Istanbul
#
#       Share of journeys to work by public transport (rail, metro, bus, tram)  \
# 0                                            675.137155
# 1                                            438.584852
# 2                                             63.683276
# 3                                            115.879833
# 4                                            229.041872
# ...                                                 ...
# ...

# %%
del db_int_pd['_id']
list_city = db_int_pd['city']
del db_int_pd['city']
list_variable = [db_int_pd.columns]

# %%
#Standardizzo tutti gli indici
db_int_pd_std = db_int_pd.apply(lambda x: (x-x.mean())/x.std())

# %%
db_int_pd_std
# Out:
#       Share of journeys to work by public transport (rail, metro, bus, tram)  \
# 0                                              0.827389
# 1                                              0.437935
# 2                                             -0.179296
# 3                                             -0.093360
# 4                                              0.092947
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
# 1001                                                NaN
#
#       Cost of a combined monthly ticket (all modes of public transport) for 5-10 km in the central zone  \
# 0                                             -0.287276
# 1                                             -0.287276
# ...

# %%
#Seleziono le variabili per creare l'indicatore Dangerousness
Index_Dangerousness = db_int_pd_std.loc[:,['People killed in road accidents per 10000 pop', 'Number of murders and violent deaths']]

# %%
#Faccio la media degli indici e ne inverto il verso 
Index_Dangerousness['Index_Dangerousness'] = Index_Dangerousness.mean(axis=1, skipna=True)*(-1)

# %%
Index_Dangerousness
# Out:
#       People killed in road accidents per 10000 pop  \
# 0                                         -0.608692
# 1                                          0.862163
# 2                                          0.796428
# 3                                         -0.806704
# 4                                         -0.736914
# ...                                             ...
# 997                                             NaN
# 998                                             NaN
# 999                                             NaN
# 1000                                            NaN
# 1001                                            NaN
#
#       Number of murders and violent deaths  Index_Dangerousness
# 0                                 0.243101             0.182796
# 1                                 0.045007            -0.453585
# 2                                -0.083688            -0.356370
# 3                                -0.035613             0.421158
# ...

# %%
Index_Culture = db_int_pd_std.loc[:,['Number of public libraries','Number of museum visitors','museum_rating', 'Cinema, International Release, 1 Seat']]

# %%
Index_Culture['Index_Culture'] = Index_Culture.mean(axis=1, skipna=True)

# %%
Index_Culture
# Out:
#       Number of public libraries  Number of museum visitors  museum_rating  \
# 0                      -0.072917                   0.020565            NaN
# 1                      -0.105037                  -0.137340            NaN
# 2                      -0.103655                  -0.139347            NaN
# 3                      -0.177128                  -0.307715            NaN
# 4                      -0.172345                  -0.302343            NaN
# ...                          ...                        ...            ...
# 997                          NaN                        NaN            NaN
# 998                          NaN                        NaN            NaN
# 999                          NaN                        NaN            NaN
# 1000                         NaN                        NaN            NaN
# 1001                         NaN                        NaN            NaN
#
#       Cinema, International Release, 1 Seat  Index_Culture
# ...

# %%
Index_Transports = db_int_pd_std.loc[:,['Share of journeys to work by public transport (rail, metro, bus, tram)','Share of journeys to work by car or motor cycle',
                                        'Length of bicycle network', 'Transport infrastructure','Share of journeys to work by bicycle',
                                        'Share of journeys to work by foot','One-way Ticket (Local Transport)','Monthly Pass (Regular Price)',
                                        'Taxi Start (Normal Tariff)','Gasoline (1 liter)']]
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
Index_Transports
# Out:
#       Share of journeys to work by public transport (rail, metro, bus, tram)  \
# 0                                              0.827389
# 1                                              0.437935
# 2                                             -0.179296
# 3                                             -0.093360
# 4                                              0.092947
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
# 1001                                                NaN
#
#       Share of journeys to work by car or motor cycle  \
# 0                                           -0.627936
# 1                                           -0.233868
# 2                                            0.306665
# ...

# %%
Index_Transports['Share of journeys to work by car or motor cycle'] = Index_Transports['Share of journeys to work by car or motor cycle']*(-1)
Index_Transports['One-way Ticket (Local Transport)'] = Index_Transports['One-way Ticket (Local Transport)']*(-1)
Index_Transports['Monthly Pass (Regular Price)'] = Index_Transports['Monthly Pass (Regular Price)']*(-1)
Index_Transports['Taxi Start (Normal Tariff)'] = Index_Transports['Taxi Start (Normal Tariff)']*(-1)
Index_Transports['Gasoline (1 liter)'] = Index_Transports['Gasoline (1 liter)']*(-1)

# %%
Index_Transports
# Out:
#       Share of journeys to work by public transport (rail, metro, bus, tram)  \
# 0                                              0.827389
# 1                                              0.437935
# 2                                             -0.179296
# 3                                             -0.093360
# 4                                              0.092947
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
# 1001                                                NaN
#
#       Share of journeys to work by car or motor cycle  \
# 0                                            0.627936
# 1                                            0.233868
# 2                                           -0.306665
# ...

# %%
Index_Transports['Index_Transports'] = Index_Transports.mean(axis=1, skipna=True)

# %%
Index_Transports
# Out:
#       Share of journeys to work by public transport (rail, metro, bus, tram)  \
# 0                                              0.827389
# 1                                              0.437935
# 2                                             -0.179296
# 3                                             -0.093360
# 4                                              0.092947
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
# 1001                                                NaN
#
#       Share of journeys to work by car or motor cycle  \
# 0                                            0.627936
# 1                                            0.233868
# 2                                           -0.306665
# ...

# %%
Index_Tweet = db_int_pd_std.loc[:,['total', 'Arrivals_19']]

# %%
Index_Tweet['Index_tweet'] = Index_Tweet.mean(axis=1, skipna=True)
Index_Tweet
# Out:
#          total  Arrivals_19  Index_tweet
# 0    -0.651885    -0.533222    -0.592553
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
# ...        ...          ...          ...
# 997        NaN          NaN          NaN
# 998        NaN          NaN          NaN
# 999        NaN          NaN          NaN
# 1000       NaN          NaN          NaN
# 1001       NaN     1.640691     1.640691
#
# [1002 rows x 3 columns]

# %%
Index_Food_rr = db_int_pd_std.loc[:,['restaurant_rating']]
Index_Food = db_int_pd_std.loc[:,[
'Meal, Inexpensive Restaurant'
,'Meal for 2 People, Mid-range Restaurant, Three-course'
,'McMeal at McDonalds (or Equivalent Combo Meal)'
,'Domestic Beer (0,5 liter draught) Restaurant'
,'Imported Beer (0,33 liter bottle) Restaurant'
,'Cappuccino (regular)'
,'Coke/Pepsi (0,33 liter bottle)'
,'Water (0,33 liter bottle)'
,'Milk (regular), (1 liter)'
,'Loaf of Fresh White Bread (500g)'
,'Rice (white), (1kg)'
,'Eggs (regular) (12)'
,'Local Cheese (1kg)'
,'Chicken Breasts (Boneless, Skinless), (1kg)'
,'Beef Round (1kg) (or Equivalent Back Leg Red Meat)'
,'Apples (1kg)'
,'Banana (1kg)'
,'Oranges (1kg)'
,'Tomato (1kg)'
,'Potato (1kg)'
,'Onion (1kg)'
,'Lettuce (1 head)'
,'Water (1,5 liter bottle)'
,'Bottle of Wine (Mid-Range)'
,'Domestic Beer (0,5 liter bottle)'
,'Imported Beer (0,33 liter bottle)']]

# %%
Index_Food_rr['index_rr'] = Index_Food_rr['restaurant_rating']*(-1)
Index_Food_rr
# Out:
#       restaurant_rating  index_rr
# 0             -1.424457  1.424457
# 1                   NaN       NaN
# 2                   NaN       NaN
# 3                   NaN       NaN
# 4                   NaN       NaN
# ...                 ...       ...
# 997                 NaN       NaN
# 998                 NaN       NaN
# 999                 NaN       NaN
# 1000                NaN       NaN
# 1001                NaN       NaN
#
# [1002 rows x 2 columns]

# %%
Index_Food['Index_Food'] = Index_Food.mean(axis=1, skipna=True)*(-1)

# %%
Index_Food
# Out:
#       Meal, Inexpensive Restaurant  \
# 0                         0.364686
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 997                            NaN
# 998                            NaN
# 999                            NaN
# 1000                           NaN
# 1001                           NaN
#
#       Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              0.171934
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# ...

# %%
Index_Food['Index_Food_rr'] = Index_Food_rr['index_rr']
Index_Food
# Out:
#       Meal, Inexpensive Restaurant  \
# 0                         0.364686
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 997                            NaN
# 998                            NaN
# 999                            NaN
# 1000                           NaN
# 1001                           NaN
#
#       Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              0.171934
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# ...

# %%
Indicator_Food = pd.DataFrame(Index_Food['Index_Food'])
Indicator_Food['Index_Food_rr']=Index_Food['Index_Food_rr']
Index_Food_and_Restaurant = Indicator_Food.mean(axis=1)
Index_Food_and_Restaurant
# Out:
# 0       0.669997
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#           ...
# 997          NaN
# 998          NaN
# 999          NaN
# 1000         NaN
# 1001         NaN
# Length: 1002, dtype: float64

# %%
Index_Housing=db_int_pd_std.loc[:,['Number of bed-places in tourist accommodation establishments'
,'Total nights spent in tourist accommodation establishments'
,'Apartment (1 bedroom) in City Centre'
,'Apartment (1 bedroom) Outside of Centre'
,'Apartment (3 bedrooms) in City Centre'
,'Apartment (3 bedrooms) Outside of Centre'
,'Price per Square Meter to Buy Apartment in City Centre'
,'Price per Square Meter to Buy Apartment Outside of Centre']]

# %%
Index_Housing['Number of bed-places in tourist accommodation establishments'] = Index_Housing['Number of bed-places in tourist accommodation establishments']*-1
Index_Housing['Total nights spent in tourist accommodation establishments'] = Index_Housing['Total nights spent in tourist accommodation establishments']*-1

# %%
Index_Housing = Index_Housing*-1

# %%
Index_Housing['Index_Housing'] = Index_Housing.mean(axis=1,skipna=True)

# %%
Index_Housing
# Out:
#       Number of bed-places in tourist accommodation establishments  \
# 0                                              0.076974
# 1                                             -0.075934
# 2                                             -0.103465
# 3                                             -0.123016
# 4                                             -0.115208
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# 999                                                 NaN
# 1000                                                NaN
# 1001                                                NaN
#
#       Total nights spent in tourist accommodation establishments  \
# 0                                              0.039811
# 1                                             -0.009938
# 2                                             -0.137072
# ...

# %%
Index_Fun = db_int_pd_std.loc[:,['Cigarettes 20 Pack (Marlboro)'
,'1 min of Prepaid Mobile Tariff Local (No Discounts or Plans)'
,'Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)'
,'Fitness Club, Monthly Fee for 1 Adult'
,'Tennis Court Rent (1 Hour on Weekend)'
,'1 Pair of Jeans (Levis 501 Or Similar)'
,'1 Summer Dress in a Chain Store (Zara, H&M, ecc)'
,'1 Pair of Nike Running Shoes (Mid-Range)'
,'1 Pair of Men Leather Business Shoes']]

# %%
Index_Fun['Index_Fun'] = Index_Fun.mean(axis=1,skipna=True)*-1

# %%
Index_Fun
# Out:
#       Cigarettes 20 Pack (Marlboro)  \
# 0                         -0.024907
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 997                             NaN
# 998                             NaN
# 999                             NaN
# 1000                            NaN
# 1001                            NaN
#
#       1 min of Prepaid Mobile Tariff Local (No Discounts or Plans)  \
# 0                                              1.131095
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 997                                                 NaN
# 998                                                 NaN
# ...

# %%
#Creazione del DataFrame che conterrà tutti gli indicatori
db_Index=pd.DataFrame()

# %%
#Importo le librerie per ottenere latitudine e longitudine delle città
import geopy
from geopy.geocoders import Nominatim

# %%
#Ottengo latitudine e longitudine delle città
lista_lat = []
lista_lon = []
for el in b['city'][c:]:
    locator = Nominatim(user_agent='d.porcellini2@campus.unimib.it')
    location = locator.geocode(str(el))
    print(el, 'Latitude = {}, Longitude = {}'.format(location.latitude, location.longitude))
    lista_lat.append(location.latitude)
    lista_lon.append(location.longitude)

# %%
lista_lon = [4.3674366933879565, 4.3997081, 3.7250121, 4.4436244, 5.5734203, 3.226772, 4.8661892, 4.7011675, 3.951958, 3.2659884, 2.919496, 23.3221789, 24.7499297, 27.9150855, -3.696977, 24.6180123, 25.9542057, 16.3725042, 25.6257235, 26.3153528, 27.900177939598652, 26.9247362, 22.88250453463423, 26.5105553, 25.925984569140283, 24.152324607853554, 23.487047631287865, 25.60865206856532, 23.715723218470906, 14.4212535, 16.6113382, 18.2820084, 13.3775249, 14.0381357, 17.251143, 15.0583947, 14.474285, 15.832719, 15.7791356, 17.6667415, 14.1025379, 12.8710769, 15.5903065, 18.4368451, 13.636112, 18.5416556, 13.4476266, 12.5700724, 10.2134046, 10.3852104, 9.9193939, 13.3888599, 10.0099133, 11.5753822, 6.959974, 8.6820917, 7.0158171, 9.1800132, 12.3747329, 13.7381437, 7.4652789, 6.7763137, 8.8071646, 9.7385532, 11.077298, 7.2196635, 8.531007, 11.960462354355379, 11.6399609, 8.2416556, 9.9352051, 6.8829192, 6.62843, 8.651177, 6.6441878, 7.8494005, 12.0974869, 11.3290855, 11.4148038, 11.0287364, 10.8986971, 7.10066, 8.4034195, 6.4353641,
 40.0271453, 56.473845999999995, 56.00205085, 51.45149525, 53.824548300000004, 51.2748258, 50.7179472, 51.768954050000005, 53.699176949999995, 41.4899827, 54.5760419, 51.7520131, 50.446247, 53.7593363, 51.7492956, 41.7002024, 53.0117627, 52.628606, 51.50342695, 53.16379785, 52.0579495, 51.8995685, 51.8653705, 51.4002688, 54.8948478, 51.1103444, 51.6553875, 59.9133301, 47.3723941, 46.2017559, 41.0766019]

# %%
#Creo tutte le variabili all'interno del dataset
db_Index['city']=list_city
db_Index['Index_Transport'] = Index_Transports['Index_Transports']
db_Index['Index_Culture'] = Index_Culture['Index_Culture']
db_Index['Index_Food'] = Index_Food_and_Restaurant
db_Index['Index_Housing'] = Index_Housing['Index_Housing']
db_Index['Index_Popularity'] = Index_Tweet['Index_tweet']
db_Index['Index_Dangerousness'] = Index_Dangerousness['Index_Dangerousness']
db_Index['Index_Fun'] = Index_Fun['Index_Fun']

# %%
db_Index
# Out:
#             city  Index_Transport  Index_Culture  Index_Food  Index_Housing  \
# 0       Brussels         1.064171       0.020911    0.669997       0.312124
# 1      Antwerpen         0.374405      -0.121189         NaN      -0.042936
# 2           Gent         0.044516      -0.121501         NaN      -0.120268
# 3      Charleroi        -0.339094      -0.242421         NaN      -0.123287
# 4          Liège        -0.143433      -0.237344         NaN      -0.060249
# ...          ...              ...            ...         ...            ...
# 997   St. Gallen              NaN            NaN         NaN            NaN
# 998       Luzern              NaN            NaN         NaN            NaN
# 999       Lugano              NaN            NaN         NaN            NaN
# 1000        Biel              NaN            NaN         NaN            NaN
# 1001   Istanbul               NaN            NaN         NaN            NaN
#
#       Index_Popularity  Index_Dangerousness  Index_Fun
# ...

# %%
#Assegno ad un nuovo Dataset il dataset con gli indicatori e mettendo come indice il nome delle città
db_Index2 = db_Index.set_index('city')

# %%
db_Index2 = db_Index2.dropna(how='all')

# %%
db_Index = db_Index2.reset_index()

# %%
#Elimino le città per cui non erano disponibili latitudine e longitudine
db_Index = db_Index.drop(index= [173, 237, 406, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 435, 569, 788, 789, 799])
db_Index['lat'] = lista_lat
db_Index['lon'] = lista_lon

# %%
db_Index
# Out:
#           city  Index_Transport  Index_Culture  Index_Food  Index_Housing  \
# 0     Brussels         1.064171       0.020911    0.669997       0.312124
# 1    Antwerpen         0.374405      -0.121189         NaN      -0.042936
# 2         Gent         0.044516      -0.121501         NaN      -0.120268
# 3    Charleroi        -0.339094      -0.242421         NaN      -0.123287
# 4        Liège        -0.143433      -0.237344         NaN      -0.060249
# ..         ...              ...            ...         ...            ...
# 948    Watford              NaN            NaN         NaN            NaN
# 949       Oslo        -1.772201       1.152144   -0.292691      -0.077591
# 950     Zurich        -1.100630       1.063117   -0.788236      -0.506337
# 951     Geneva        -0.712193       0.840179   -0.386669      -0.693835
# 952  Istanbul               NaN            NaN         NaN            NaN
#
#      Index_Popularity  Index_Dangerousness  Index_Fun        lat        lon
# ...

# %%
#Trasformo in un file json
json_file = [{**x[i]} for i, x in db_Index.stack().groupby(level=0)]

# %%
#Importo su Mongo
client.Integrated_db.integrated_index_collection_coordinates.insert_many(json_file)
